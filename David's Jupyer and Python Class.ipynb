# %% [markdown]
# # Jaakia is awesome and so is her heading
# * this is a bullet
#  * this is another bullet
#
#  This is some random text that David told me to type.

# %%
print ("Jaakia is still awesome!")
# Out:
# Jaakia is still awesome!
